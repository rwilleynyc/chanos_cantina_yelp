# %%
import time as t
from lxml import html 
import requests

inputs = pd.read_csv('firm_data/inputs.csv', usecols=[1,2,3])
name = inputs['company_name'][0]
search_terms = inputs['search_terms'][0]
location = inputs['location'][0]

raw_data = pd.read_csv('firm_data/competitors.csv', 
                       usecols=[1, 2, 4, 6, 7, 8, 9])

data = raw_data.copy()
data
# Out:
#                                        alias                            name  \
# 0                     chanos-cantina-astoria                 Chano's Cantina
# 1                             tacuba-astoria                          Tacuba
# 2           frescos-cantina-long-island-city                Fresco's Cantina
# 3              lunera-modern-mexican-astoria           Lunera Modern Mexican
# 4                            trestle-astoria                         Trestle
# 5   juquila-kitchen-and-bar-long-island-city         Juquila Kitchen and Bar
# 6                       the-astorian-astoria                    The Astorian
# 7     the-brewery-bar-and-kitchen-woodside-2       The Brewery Bar & Kitchen
# 8                 la-pulperia-ues-new-york-3                 La Pulperia UES
# 9  cantina-taqueria-and-tequila-bar-new-york  Cantina Taqueria & Tequila Bar
#
#    review_count  rating  price     distance  \
# 0           164     4.0    2.0  1290.427488
# 1           644     3.5    2.0  1229.351705
# 2           209     4.5    2.0   927.218713
# 3           112     4.0    2.0   986.258835
# 4           289     4.0    2.0   700.500655
# 5            98     4.0    2.0  1829.249006
# 6           165     4.5    2.0    91.375358
# 7           114     4.5    2.0  1453.201140
# 8           723     4.0    2.0  2758.509541
# 9           492     4.0    2.0  4627.750977
#
#                                              tags
# 0           Cocktail Bars New Mexican Cuisine 2.0
# 1           Mexican Tapas Bars Latin American 2.0
# 2  Mexican Latin American New Mexican Cuisine 2.0
# 3          Latin American New Mexican Cuisine 2.0
# 4                Cocktail Bars American (New) 2.0
# 5     New Mexican Cuisine Tacos Cocktail Bars 2.0
# 6     Gastropubs Cocktail Bars American (New) 2.0
# 7    Sports Bars American (Traditional) Irish 2.0
# 8        Latin American Seafood Cocktail Bars 2.0
# 9        Mexican Latin American Cocktail Bars 2.0

# %%
url = 'https://www.yelp.com/biz/' + data['alias'][0] + '?start=20'

html_page = requests.get(url) #Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing

# %%
pg_count = 'lemon--span__373c0__3997G text__373c0__2pB8f text-color--inherit__373c0__w_15m text-align--left__373c0__2pnx_'
num_pages = int(soup.find_all('span', class_=pg_count)[2].text[-2:])
num_pages
# Out:
# 9
